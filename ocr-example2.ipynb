# %%
from PIL import Image
import pytesseract as pt

image = Image.open('/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/hwanhwa1.png')

# pt.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract' #TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information. 에러 메시지 나올 경우
text = pt.image_to_string(image, lang='kor')
# text = pt.image_to_string(image, config="-l kor")
print(text)
# Out:
# 65리테일 (007070)
#
# 회복과 시너지를 기대
#
# 2022년에는 본업
#
# 2022년 01월 13일
# 기업분석
#
# 4004040404040444044044404444444444444444444444404444044404044404040407/4
#
# 640 (유지)
#
# 목표주가(유지): 60,000원
#
# 현재주가0/12:
# 상숭여력
#
# 시가총액
#
# 발행주식수
#
# 152주 최고가 / 최저가
# 90일 일평균 거라대금
# 외국인 지분율
#
# 주주 구성
#
# 65(외2인
#
# 국민면금공단 (의 1인)
# 자사주 (외1 엔
#
# 주가수익률(%)
# 절대수익률
#
# 상대수익률(<050)'
#
# 재무점보
# 마올역
#
# 영업이익
# 008
#
# 지바주주순이익
#
# 20060006
# 바당수익를
#
# 때
#
# 주가추이
#
# 「
# @0.000     -- 652티일
#
# 16050지수대비
#
# 40000 부스
#
# 20.000
#
# ㅁ
# 2101 2104 21707
#
# 29.600원
#
# 소1027
# 30.997억원
# 104.718천주
# 39.250728.250원
# 66.32억원
#
# 81%
#
# 5799
# 83
# 24%
#
# '6개월. 12개월
# 786 787
# 704 732
# 십억원 원.%,배'
# 20216 20225
# 9698 11212
# 248 355
#
# 0
# 2110 ㆍ 2201
#
# > 40809! 남성현 000826701720\78.0007 3772-7651
#
# 4분기 영업실적은 부진한 흐름 이어질 전망
# (65리테일 4분기 영업심적은 부진할 것으로 전망한다. 4분기 연결기준
# 매출액은 2조 5,867억 원(전년동기대비 +19.7%), 영업이익 622억 원
# 에(전년동기대비 +142.19) 달할 것으로 추정한다. 합병기준으로 전환
# 해보면 매출액은 전년동기대비 +3.5%, 영업이익은 전년동기대비
# -13.5%으로 분석한다.
# ...

# %%
from PIL import Image
import pytesseract as pt

image = Image.open('/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/hwanhwa1.png')

# pt.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract' #TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information. 에러 메시지 나올 경우
text = pt.image_to_string(image, lang='kor+eng')
# text = pt.image_to_string(image, config="-l kor")
print(text)
# Out:
# 65리테일 (007070)
#
# 회복과 시너지를 기대
#
# 2022년에는 본업
#
# 2022년 01월 13일
# 기업분석
#
# PLL LLL
#
# BUY (22)
#
# 목표주가(유지): 60,0008
#
# PTD
# 상숭여력
#
# 시가총액
#
# ware
#
# 52% 최고가 / 최저가
# 908 일평균 IH
# 외국인 지분율
#
# 주주 구성
#
# 65(외2인
#
# 국민면금공단 (el 1인)
# 자사주 (외1 2)
#
# 주가수익률(%)
# 절대수익률
#
# 상대수익률(<050)'
#
# 재무점보
# oie
# gore,
# EBITDA
#
# 지바주주순이익
#
# EV/EBIDA
# ASSO
#
# ROE
#
# 주가추이
#
# @
# 60,000     ssa
#
# 16050지수대비
#
# 40,000 bev drapes
#
# 20,000
#
# °
# 2101 21/04 21707
#
# 29,6008
#
# 소1027
# 30.997억원
# 104.718천주
# 39.250728.250원
# 66.32억원
#
# 81%
#
# 579%
# 83%
# 2.4%
#
# one 12개월
# 786 787
# 704 732
# 십억원 원.%,배'
# 20216 20225
# 9698 11212
# 248 355
#
# 0
# 2110 ㆍ 2201
#
# > Analyst 남성현 gone267@hanwha.com 3772-7651
#
# 4분기 영업실적은 부진한 흐름 이어질 전망
# (65리테일 4분기 영업심적은 HAS 것으로 전망한다. 4분기 연결기준
# 매출액은 2% 58679 원(전년동기대비 +19.7%), 영업이익 622억 원
# 에(전년동기대비 +142.1%) 달할 것으로 추정한다. 합병기준으로 전환
# 해보면 매출액은 전년동기대비 +3.5%, 영업이익은 전년동기대비
# -13.5%으로 분석한다.
# 기 부진한 AAS 전망하는 DHE 1) 사회적거리두기 강화 및 추
# ...

# %%
from PIL import Image
import pytesseract as pt

image = Image.open('/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/hwanhwa2.png')

# pt.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract' #TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information. 에러 메시지 나올 경우
text = pt.image_to_string(image, lang='kor')
# text = pt.image_to_string(image, config="-l kor")
print(text)
# Out:
# 65리테일 (007070)                                                       [한화리서치]
#
#
#
# [ 종목 투자등급 ]
#
#
#
# SAKE 7H 종목에 대해 향후 1 년간 +15% 이상의 절다수익률이 기대되는 종목에 다해 BuyOH) 의견을 제시합니다. 또한 절대수
# 익률-15-+159가여상되는 종목에 다해 00보유) CIB, -15% 이하가 예상되는 종목에 대해 SMOKE) OLAS 제시합니다. 밸류
# 에이션 방법 등 절대수익률 AS 개별 SRS 커버하는 애널리스트의 추정에 따르며, 목표주가 산정이나 투자의견 변경 주기는 종
# 목별로 다릅니다
#
# [ 산업 투자의견 ]
#
# SAKE 산업에 대해 향후 1 년간 해당 업종의 수익률이 과거 수익률에 비해 양호한 SSS 보일 것으로 예상되는 경우에 005066(긍정
# A) 의견을 제시하고 있습니다. 또한 향후 1 년간 수익률이 과거 수익률과 유사한 SSS 보일 것으로 예상되는 경우에 NeutralS2A)
# SAS, 과거 수익률보다 부진한 SSS 보일 것으로 예상되는 경우에 1698066\부정적) 의견을 제시하고 있습니다. 산업별 수익률 전
# 망은 해당 산업 내 분석대상 종목들에 대한 담당 애널리스트의 분석과 판단에 따릅니다.
#
#
#
#
#
# [ 당사 조사분석자료의 투자등급 부여 비중 ]                      (기준일:2021년 12월 31 일)
# 투자등급                                      매수                 중립                 매도                 합계
#
#
#
#
#
#
#
#
#
#
#
# 금융투자상품의 비중                    97.7%           23%            0.0%           100.0%

# %%
from PIL import Image
import pytesseract as pt

image = Image.open('/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/hwanhwa2.png')

# pt.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract' #TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information. 에러 메시지 나올 경우
text = pt.image_to_string(image, lang='kor+eng')
# text = pt.image_to_string(image, config="-l kor")
print(text)
# Out:
# 65리테일 (007070)                                                       [한화리서치]
#
#
#
# [ 종목 투자등급 ]
#
#
#
# SAKE 7H 종목에 대해 향후 1 년간 +15% 이상의 절다수익률이 기대되는 종목에 다해 BuyOH) 의견을 제시합니다. 또한 절대수
# 익률-15-+159가여상되는 종목에 다해 00보유) CIB, -15% 이하가 예상되는 종목에 대해 SMOKE) OLAS 제시합니다. 밸류
# 에이션 방법 등 절대수익률 AS 개별 SRS 커버하는 애널리스트의 추정에 따르며, 목표주가 산정이나 투자의견 변경 주기는 종
# 목별로 다릅니다
#
# [ 산업 투자의견 ]
#
# SAKE 산업에 대해 향후 1 년간 해당 업종의 수익률이 과거 수익률에 비해 양호한 SSS 보일 것으로 예상되는 경우에 005066(긍정
# A) 의견을 제시하고 있습니다. 또한 향후 1 년간 수익률이 과거 수익률과 유사한 SSS 보일 것으로 예상되는 경우에 NeutralS2A)
# SAS, 과거 수익률보다 부진한 SSS 보일 것으로 예상되는 경우에 1698066\부정적) 의견을 제시하고 있습니다. 산업별 수익률 전
# 망은 해당 산업 내 분석대상 종목들에 대한 담당 애널리스트의 분석과 판단에 따릅니다.
#
#
#
#
#
# [ 당사 조사분석자료의 투자등급 부여 비중 ]                      (기준일:2021년 12월 31 일)
# 투자등급                                      매수                 중립                 매도                 합계
#
#
#
#
#
#
#
#
#
#
#
# 금융투자상품의 비중                    97.7%           23%            0.0%           100.0%

# %%
# 한화투자증권-남성현-1.png

from PIL import Image
import pytesseract as pt

image = Image.open('/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/한화투자증권-남성현-6.png')

# pt.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract' #TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information. 에러 메시지 나올 경우
text = pt.image_to_string(image, lang='kor+eng')
# text = pt.image_to_string(image, config="-l kor")
print(text)
# Out:
#
#
#
#
# 65리테일 (007070)                                                 [한화리서치]
# [ 종목 투자등급 ]
#
# Sate 개별 BRO 대해 향후 1 년간 +15% 이상의 절다수익률이 기되는 BON 다해 Buy) SIS 제시합니다. 또한 ACH
# 익률 -15~+15%가 예상되는 종목에 대해 100!보유) SAS, -15% 이하가 예상되는 종목에 대해 56!(매도) =) 의견을 제시합니다. 밸류
#
# 에이션 방법 등 절대수익률 산정은 개별 종목을 커버하는 야널리스트의 추정에 따르며, 목표주가 산정이나 투자의견 변경 주기
#
# 목별로 다릅니다.
#
# 0 yy
# of
#
# 견 변경 주.
#
#
#
# 당사는 산업에 대해 향후 1 년간 해당 업종의 수익률이 과거 수익률에 비해 양
#
# 적) 의견을 제시하고 있습니다. 또한 향후 1 년간 수익률이 과거 수익률과 유사한
# 의견을, 과거 수익률보다 부진한 SSS 보일 것으로 예상되는 경우에 Negative
# 망은 해당 산업 내 분석대상 종목들에 대한 담당 애널리스트의 분석과 판단에 Ch
#
# [
#
# 당사 조사분석자료의 투자등급 부여 비중 ]
#
#
#
#
#
# 경우에 005008(긍정
# 우에 46008(중립적)
# 전
#
# 정적) 의견을 제시하고 있습니다. 산업별 수익률 전
# 니다.
#
#
#
#
#
# 투자등급                                                  매수                      중립                      매도                      합계
# 금융투자상품의 비중                                  97.7%                    2.3%                    0.0%                   100.0%

# %%
# 한화투자증권-남성현-1.png

from PIL import Image
import pytesseract as pt

image = Image.open('/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/한화투자증권-남성현-1.png')

# pt.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract' #TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information. 에러 메시지 나올 경우
text = pt.image_to_string(image, lang='kor+eng')
# text = pt.image_to_string(image, config="-l kor")
print(text)
# Out:
# anu
#
# 는                          2022년 01월 13일
# x                aoansSsS
# (9 한화투자증권             errr
#
# (35리테일 (07070)
# 2022년에는 본업 회복과 시너지를 기대
#
# 42040040444444444444444044444040444040404040404040404040404040404040404040400040004/
# > Analyst 남성현 gone267@hanwha.com 3772-7651
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# BUY (22)          4분기 영업실적은 부진한 흐름 이어질 전망
# aa                          (35리테일 4분기 영업실적은 부진할 것으로 전망한다. 4분기 연결기준
# (무00/0/으|         의                   ㆍ
# 콕표주가(유지): 60,000원            매출액은 2조 5.867억 원(전년동기대비 +19.7%), 영업이익 622억 원
# —                         nee «© 에(전년동기대비 +142.198) 달할 것으로 추정한다. 합병기준으로 전환
# Aso                          102.7% 해보면 매출액은 전년동기대비 43.5%, 영업이익은 전년동기대4
# 시가총액                                   30.997억원         -13.5%으로 분석한다.
# 발행주식수                               104,718천주             .          were
# 52 주 최고가 / 최저가                      39,250/ 28,250원
# ...
