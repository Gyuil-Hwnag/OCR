# %%
# import parser object from tike
from tika import parser  
  
# opening pdf file
pdfs = r"/Users/hwang-gyuil/Desktop/더미데이터OCR용/한화투자증권/한화투자증권-남성현.pdf"
parsed_pdf = parser.from_file(pdfs)
  
# saving content of pdf
# you can also bring text only, by parsed_pdf['text'] 
# parsed_pdf['content'] returns string 
data = parsed_pdf['content'] 
  
# Printing of content 
print(data)
  
# <class 'str'>
print(type(data))
# Out:
# 2022년 01월 13일
#
# 기업분석
#
#
#
#
#
#
#
# GS리테일 (007070)
# 2022년에는 본업 회복과 시너지를 기대
#
#
# ▶Analyst 남성현 gone267@hanwha.com 3772-7651
#
#
#
# BUY (유지)
# 목표주가(유지): 60,000원
#
#
# 현재 주가(1/12) 29,600원
#
# 상승여력 ▲102.7%
#
# 시가총액 30,997억원
#
# 발행주식수 104,718천주
#
# 52 주 최고가 / 최저가 39,250 / 28,250원
#
# 90 일 일평균 거래대금 66.32억원
#
# 외국인 지분율 8.1%
#
#
#
# 주주 구성
#
# GS (외 2인) 57.9%
#
# 국민연금공단 (외 1인) 8.3%
#
# 자사주 (외 1 인) 2.4%
#
#
# 주가수익률(%) 1개월 3개월 6개월 12개월
#
# 절대수익률 -5.7  -8.2  -18.8  -18.1
#
# 상대수익률(KOSPI) -4.5  -10.1  -10.4  -13.2
#
# (단위: 십억 원, 원, %, 배)
#
# 재무정보 2019 2020 2021E 2022E
#
# 매출액 9,007  8,862  9,698  11,212
#
# 영업이익 239  253  248  355
#
# EBITDA 898  921  968  1,161
#
# 지배주주순이익 133  168  875  362
#
# EPS 1,729  2,187  8,771  3,454
#
# 순차입금 2,696  2,593  2,101  1,591
#
# PER 22.7  15.7  3.5  8.6
#
# PBR 1.4  1.2  0.8  0.7
#
# EV/EBITDA 6.4  5.7  5.5  4.0
#
# 배당수익률 1.9  2.6  3.1  3.7
#
# ROE 6.2  7.5  27.4  8.6
#
#
# 주가 추이
#
#
#
#
#
#
# 4분기 영업실적은 부진한 흐름 이어질 전망
#
# GS리테일 4분기 영업실적은 부진할 것으로 전망한다. 4분기 연결기준
#
# 매출액은 2조 5,867억 원(전년동기대비 +19.7%), 영업이익 622억 원
#
# 에(전년동기대비 +142.1%) 달할 것으로 추정한다. 합병기준으로 전환
#
# 해보면 매출액은 전년동기대비 +3.5%, 영업이익은 전년동기대비
#
# -13.5%으로 분석한다.
#
# 4분기 부진한 실적을 전망하는 근거는 1) 사회적거리두기 강화 및 추
#
# 운 날씨 여파로 편의점 집객력이 하락하였고, 2) 슈퍼마켓 사업부 부진
#
# 과, 3) 채널수수료 증가에 따른 홈쇼핑 비용 부담 증가가 예상되기 때
#
# 문이다.
#
# 실적 둔화에도 기대되는 이유
#
# 부진한 실적 흐름은 1분기를 기점으로 개선될 것으로 전망한다. 그러
#
# 한 이유는 1) 홈쇼핑 사업부에 대한 기저가 낮아지고, 2) 외부활동 증
#
# 가에 따라 편의점 집객력 상승이 예상되며, 3) 슈퍼마켓 사업부 비수익
#
# 점포 개선 지속, 4) 홈쇼핑과의 합병 시너지가 기대되기 때문이다.
#
# 동사는 올해 ▶ 홈쇼핑과의 시너지 본격화, ▶ 요기요와의 협업을 통한
#
# 비즈니스 모델 구축, ▶ 온·오프라인 채널 구축을 통한 차별적인 경쟁
#
# 력 확보가 이루어질 것으로 전망한다.
#
# 투자의견 BUY, 목표주가 6만원 유지
#
# 동사에 대한 투자의견 BUY와 목표주가 6만원을 유지한다. 목표주가와
#
# 실질 주가와의 괴리율 차이가 크지만, ▶ 2022년 실적 기준 PER 수준
#
# 은 8.6배에 불과하고, ▶ 연간 EBITDA 창출능력이 약 9천억원(사용권
#
# 자산상각비 제외) 수준에 달하며, ▶ 주요 사업부인 편의점과 홈쇼핑
#
# 이익 창출능력이 안정적이고, ▶ 현금흐름창출능력을 기반으로 공격적
#
# 인 투자가 가능한 구조라는 점에서 향후 기업가치 상승 가능성은 높은
#
# 것으로 전망한다. 또한, 2021년 예상 DPS는 약 950원, 2022년 예상
#
# DPS는 1,100원으로 배당매력도 높다. 이에 투자의견 BUY와 목표주가
#
# 6만원을 제시한다.
#
#
#
# 0
#
# 50
#
# 100
#
# 150
#
# 0
#
# 20,000
#
# 40,000
#
# 60,000
#
# 21/01 21/04 21/07 21/10 22/01
#
# (pt)(원)
#
# GS리테일
#
# KOSPI지수대비
#
#
#
# GS리테일 (007070) [한화리서치]
#
#
#
#
#
#
#
# 2
#
# [표1] GS 리테일 분기 및 연간 실적 추이(연결기준)  (단위: 십억 원, %)
#
#  1Q20 2Q20 3Q20 4Q20 1Q21 2Q21 3Q21 4Q21E 2020 2021E 2022E
#
# 매출액 2,141.9  2,210.7  2,348.8  2,160.9  2,100.1  2,285.6  2,725.4  2,586.7  8,862.3  9,697.8  11,212.1
#
# YoY, % 2.8  -4.2  -1.1  -3.6  -2.0  3.4  16.0  19.7  -1.4  9.4  15.6
#
# _편의점 1,602.8  1,762.9  1,878.6  1,727.2  1,647.9  1,816.0  1,925.2  1,778.3  6,971.5  7,167.4  7,918.1
#
# _홈쇼핑 - - - - - - 293.1  330.0  - 623.1  1,276.1
#
# _슈퍼마켓 345.1  314.6  389.3  284.7  298.5  297.4  326.4  278.3  1,333.7  1,200.6  1,233.9
#
# _기타 148.7  97.2  100.3  104.8  108.5  119.5  131.2  125.1  451.0  484.3  557.5
#
# _파르나스호텔 45.3  36.0  40.5  65.2  45.2  52.6  49.4  75.0  187.0  222.2  226.6
#
# 매출원가 1,659.5  1,763.4  1,863.1  1,745.1  1,685.4  1,835.1  2,029.8  1,849.5  7,031.0  7,399.7  8,345.9
#
# YoY, % 0.8  -2.1  0.9  -1.4  1.6  4.1  8.9  6.0  3.5  5.2  12.8
#
# 매출총이익 482.4  447.3  485.7  415.8  414.8  450.5  695.7  737.2  1,831.3  2,298.1  2,866.2
#
# YoY, % 10.7  -11.6  -8.1  -11.9  -14.0  0.7  43.2  77.3  4.1  25.5  24.7
#
# 매출총이익률, % 22.5  20.2  20.7  19.2  19.8  19.7  25.5  28.5  20.7  23.7  25.6
#
# 판관비 393.6  388.2  406.8  390.2  377.2  407.7  593.2  671.7  1,578.7  2,049.8  3,251.3
#
# YoY, % -5.0  -9.5  -7.1  -7.5  -4.2  5.0  45.8  72.1  1.0  29.8  58.6
#
# 영업이익 88.8  59.2  79.0  25.7  37.5  42.8  102.5  62.2  252.6  248.4 351.0
#
# YoY, % 314.7  -23.2  -12.8  -48.5  -57.7  -27.7  29.8  142.1  32.5  -1.6  41.3
#
# 영업이익률, % 4.1  2.7  3.4  1.2  1.8  1.9  3.8  2.4  2.8  2.6  3.1
#
#
# 주: ‘21년 3분기 GS홈쇼핑 합병
#
# 자료: GS리테일, 한화투자증권 리서치센터
#
#
#
#
#
#
#
#
#
# GS리테일 (007070) [한화리서치]
#
#
#
#
#
#
#
# 3
#
#  [그림1] 외부활동 증가 추이 지속
#
#
#
#
#
#
# 주: ’20.01.03. ~ ’20.02.06.의 방문자 중앙값 기준. 7일 이동평균법으로 조정
#
# 자료: 구글 <코로나 19 지역사회 이동성 보고서>, 한화투자증권 리서치센터
#
#
#
# [그림2] 전년동기대비 편의점 기존점포 성장률 추이  [그림3] 전년동기대비 편의점 품목별 성장률 추이
#
#
#
#
#
#
#
# 자료: 산업통상자원부, 한화투자증권 리서치센터  자료: 산업통상자원부, 한화투자증권 리서치센터
#
#
# [그림4] GS 홈쇼핑 모바일사업부 취급고 추이  [그림5] 온라인시장 규모 동향
#
#
#
#
#
#
#
# 자료: GS홈쇼핑, GS리테일, 한화투자증권 리서치센터  자료: 통계청, 한화투자증권 리서치센터
#
#
#
# -40
#
# -20
#
# 0
#
# 20
#
# 40
#
# 60
#
# 80
#
# 20/02 20/06 20/10 21/02 21/06 21/10
#
# (%)
#
# 소매점 및 여가시설 식료품점
#
# -12
#
# -9
#
# -6
#
# -3
#
# 0
#
# 3
#
# 6
#
# 19/01 19/06 19/11 20/04 20/09 21/02 21/07
#
# (%)
#
# 기존점
#
# -20
#
# -15
#
# -10
#
# -5
#
# 0
#
# 5
#
# 10
#
# 15
#
# 20
#
# 19/01 19/06 19/11 20/04 20/09 21/02 21/07
#
# (%)
#
# 담배 등 기타 음료 등 가공 즉석 (신선일부)
#
# 0
#
# 5
#
# 10
#
# 15
#
# 20
#
# 25
#
# 30
#
# 0
#
# 150
#
# 300
#
# 450
#
# 600
#
# 750
#
# 900
#
# 1Q19 3Q19 1Q20 3Q20 1Q21 3Q21
#
# (십억원) (%)
#
# 취급고 성장률(우)
#
# 0
#
# 5
#
# 10
#
# 15
#
# 20
#
# 25
#
# 30
#
# 0
#
# 10
#
# 20
#
# 30
#
# 40
#
# 50
#
# 60
#
# 1Q19 3Q19 1Q20 3Q20 1Q21 3Q21
#
# (조원) (%)
#
# 온라인 시장 성장률(우)
#
#
#
# GS리테일 (007070) [한화리서치]
#
#
#
#
#
#
#
# 4
#
# [ 재무제표 ]
#
# 손익계산서 (단위: 십억 원)  대차대조표 (단위: 십억 원)
#
# 월 결산 2019 2020 2021E 2022E 2023E  월 결산 2019 2020 2021E 2022E 2023E
#
# 매출액 9,007  8,862  9,698  11,212  12,056   유동자산 800  923  1,574  1,976  2,299
#
# 매출총이익 1,942  1,831  2,298  2,866  3,002   현금성자산 248  362  927  1,297  1,586
#
# 영업이익 239  253  248  355  404   매출채권 267  274  288  303  318
#
# EBITDA 898  921  968  1,161  1,151   재고자산 183  189  255  268  281
#
# 순이자손익 -30  -10  21  100  110   비유동자산 6,249  6,254  7,780  7,582  7,477
#
# 외화관련손익 0  0  0  0  0   투자자산 3,816  3,844  4,943  5,144  5,367
#
# 지분법손익 -1  -7  38  1  1   유형자산 2,297  2,299  2,585  2,256  1,978
#
# 세전계속사업손익 200  201  972  476  536   무형자산 136  112  252  182  133
#
# 당기순이익 144  155  865  362  407   자산총계 7,050  7,178  9,354  9,558  9,776
#
# 지배주주순이익 133  168  875  362  407   유동부채 1,777  1,682  1,903  1,854  1,828
#
# 증가율(%)       매입채무 531  570  599  629  660
#
# 매출액 3.6  -1.6  9.4  15.6  7.5   유동성이자부채 875  738  783  683  603
#
# 영업이익 32.5  5.7  -1.7  43.1  13.6   비유동부채 2,705  2,828  3,006  2,997  2,950
#
# EBITDA 86.6  2.6  5.1  20.0  -0.9   비유동이자부채 2,069  2,217  2,244  2,204  2,124
#
# 순이익 8.5  7.6  459.8  -58.2  12.5   부채총계 4,483  4,511  4,910  4,852  4,777
#
# 이익률(%)            자본금 77  77  105  105  105
#
# 매출총이익률 21.6  20.7  23.7  25.6  24.9   자본잉여금 156  156  1,204  1,204  1,204
#
# 영업이익률 2.7  2.8  2.6  3.2  3.3   이익잉여금 1,969  2,083  2,889  3,151  3,443
#
# EBITDA이익률 10.0  10.4  10.0  10.4  9.5   자본조정 -11  -12  -119  -119  -119
#
# 세전이익률 2.2  2.3  10.0  4.2  4.4   자기주식 0  0  -98  -98  -98
#
# 순이익률 1.6  1.7  8.9  3.2  3.4   자본총계 2,567  2,667  4,444  4,707  4,999
#
#
#
# 현금흐름표 (단위: 십억 원)  주요지표 (단위: 원, 배)
#
# 월 결산 2019 2020 2021E 2022E 2023E  월 결산 2019 2020 2021E 2022E 2023E
#
# 영업현금흐름 804  806  807  1,208  1,196   주당지표
#
# 당기순이익 144  155  865  362  407   EPS 1,729  2,187  8,771  3,454  3,887
#
# 자산상각비 659  669  719  806  747   BPS 28,443  29,928  38,955  41,459  44,246
#
# 운전자본증감 -85  -40  -72  19  19   DPS 750  900  950  1,100  1,200
#
# 매출채권 감소(증가) 2  -1  5  -14  -15   CFPS 12,680  12,655  9,926  11,354  11,237
#
# 재고자산 감소(증가) 42  -5  -31  -13  -13   ROA(%) 2.2  2.4  10.6  3.8  4.2
#
# 매입채무 증가(감소) -44  20  -109  30  31   ROE(%) 6.2  7.5  27.4  8.6  9.1
#
# 투자현금흐름 -301  -391  -234  -624  -659   ROIC(%) 4.1  3.8  4.0  4.7  5.5
#
# 유형자산처분(취득) -251  -297  -278  -393  -405   Multiples(x,%)
#
# 무형자산 감소(증가) -1  -4  -10  -5  -5   PER 22.7  15.7  3.5  8.6  7.6
#
# 투자자산 감소(증가) -30  -166  -45  -26  -27   PBR 1.4  1.2  0.8  0.7  0.7
#
# 재무현금흐름 -507  -436  -489  -239  -275   PSR 0.3  0.3  0.3  0.3  0.3
#
# 차입금의 증가(감소) -825  -373  -427  -140  -160   PCR 3.1  2.7  3.1  2.6  2.6
#
# 자본의 증가(감소) -54  -62  -69  -99  -115   EV/EBITDA 6.4  5.7  5.5  4.0  3.7
#
# 배당금의 지급 -54  -62  -69  -99  -115   배당수익률 1.9  2.6  3.1  3.7  4.1
#
# 총현금흐름 976  974  991  1,189  1,177   안정성(%)
#
# (-)운전자본증가(감소) 21  -33  -90  -19  -19   부채비율 174.6  169.1  110.5  103.1  95.6
#
# (-)설비투자 269  318  304  393  405   Net debt/Equity 105.0  97.2  47.3  33.8  22.8
#
# (+)자산매각 17  17  16  -5  -5   Net debt/EBITDA 300.2  281.5  217.1  137.0  99.2
#
# Free Cash Flow 704  706  793  809  786   유동비율 45.0  54.9  82.7  106.6  125.8
#
# (-)기타투자 84  -4  65  200  222   이자보상배율(배) 3.3  3.7  3.9  5.5  6.7
#
# 잉여현금 620  710  729  609  564   자산구조(%)
#
# NOPLAT 172  194  221  270  307   투하자본 55.9  55.0  50.3  46.8  44.1
#
# (+) Dep 659  669  719  806  747   현금+투자자산 44.1  45.0  49.7  53.2  55.9
#
# (-)운전자본투자 21  -33  -90  -19  -19   자본구조(%)
#
# (-)Capex 269  318  304  393  405   차입금 53.4  52.6  40.5  38.0  35.3
#
# OpFCF 542  578  727  701  669   자기자본 46.6  47.4  59.5  62.0  64.7
#
# 주: IFRS 연결 기준
#
#
#
#
#
# GS리테일 (007070) [한화리서치]
#
#
#
#
#
#
#
# 5
#
# [ Compliance Notice ] (공표일: 2022년 01 월 13 일)
#
# 이 자료는 조사분석 담당자가 객관적 사실에 근거해 작성하였으며, 타인의 부당한 압력이나 간섭없이 본인의 의견을 정확하게
#
# 반영했습니다. 본인은 이 자료에서 다룬 종목과 관련해 공표일 현재 관련 법규상 알려야 할 재산적 이해관계가 없습니다. 본인은 이
#
# 자료를 기관투자자 또는 제3 자에게 사전에 제공한 사실이 없습니다. (남성현)
#
# 저희 회사는 공표일 현재 이 자료에서 다룬 종목의 발행주식을 1% 이상 보유하고 있지 않습니다.
#
# 이 자료는 투자자의 증권투자를 돕기 위해 당사 고객에 한하여 배포되는 자료로서 저작권이 당사에 있으며 불법 복제 및 배포를 금
#
# 합니다. 이 자료에 수록된 내용은 당사 리서치센터가 신뢰할 만한 자료나 정보출처로부터 얻은 것이지만, 당사는 그 정확성이나 완
#
# 전성을 보장할 수 없습니다. 따라서 이 자료는 어떠한 경우에도 고객의 증권투자 결과와 관련된 법적 책임소재에 대한 증빙으로 사
#
# 용될 수 없습니다.
#
#
#
# [ GS리테일 주가와 목표주가 추이 ]
#
#
#
#
#
# [ 투자의견 변동 내역 ]
#
# 일    시 2016.08.12 2020.02.06 2020.04.09 2020.04.28 2020.05.25 2020.07.09
#
# 투자의견 투자등급변경 Buy Buy Buy Buy Buy
#
# 목표가격  53,000 40,000 50,000 60,000 60,000
#
# 일    시 2020.08.10 2020.10.14 2020.10.28 2020.11.11 2020.11.18 2021.01.20
#
# 투자의견 Buy Buy Buy Buy Buy Buy
#
# 목표가격 60,000 60,000 60,000 60,000 60,000 60,000
#
# 일    시 2021.01.27 2021.02.09 2021.04.27 2021.06.25 2021.07.12 2021.08.05
#
# 투자의견 Buy Buy Buy Buy Buy Buy
#
# 목표가격 60,000 60,000 60,000 60,000 60,000 60,000
#
# 일    시 2021.09.08 2022.01.13
#
# 투자의견 Buy Buy
#
# 목표가격 60,000 60,000
#
#
#
# [ 목표주가 변동 내역별 괴리율 ]
#
# 일자 투자의견 목표주가(원)
# 괴리율(%)
#
# 평균주가 대비 최고(최저)주가 대비
#
# 2020.04.09 Buy            40,000  -20.42  -8.75
#
# 2020.04.28 Buy            50,000  -20.79  -14.40
#
# 2020.05.25 Buy            60,000  -40.37  -26.92
#
# 2021.06.25 Buy            60,000
#
#
#
#
#
#
# 0
#
# 20,000
#
# 40,000
#
# 60,000
#
# 80,000
#
# 20/01 20/04 20/07 20/10 21/01 21/04 21/07 21/10
#
# (원)
#
# 종가 목표주가
#
#
#
# GS리테일 (007070) [한화리서치]
#
#
#
#
#
#
#
# 6
#
# [ 종목 투자등급 ]
#
# 당사는 개별 종목에 대해 향후 1 년간 +15% 이상의 절대수익률이 기대되는 종목에 대해 Buy(매수) 의견을 제시합니다. 또한 절대수
#
# 익률 -15~+15%가 예상되는 종목에 대해 Hold(보유) 의견을, -15% 이하가 예상되는 종목에 대해 Sell(매도) 의견을 제시합니다. 밸류
#
# 에이션 방법 등 절대수익률 산정은 개별 종목을 커버하는 애널리스트의 추정에 따르며, 목표주가 산정이나 투자의견 변경 주기는 종
#
# 목별로 다릅니다.
#
#
#
# [ 산업 투자의견 ]
#
# 당사는 산업에 대해 향후 1 년간 해당 업종의 수익률이 과거 수익률에 비해 양호한 흐름을 보일 것으로 예상되는 경우에 Positive(긍정
#
# 적) 의견을 제시하고 있습니다. 또한 향후 1 년간 수익률이 과거 수익률과 유사한 흐름을 보일 것으로 예상되는 경우에 Neutral(중립적)
#
# 의견을, 과거 수익률보다 부진한 흐름을 보일 것으로 예상되는 경우에 Negative(부정적) 의견을 제시하고 있습니다. 산업별 수익률 전
#
# 망은 해당 산업 내 분석대상 종목들에 대한 담당 애널리스트의 분석과 판단에 따릅니다.
#
#
#
# [ 당사 조사분석자료의 투자등급 부여 비중 ] (기준일: 2021년 12 월 31 일)
#
# 투자등급 매수 중립 매도 합계
#
# 금융투자상품의 비중 97.7% 2.3% 0.0% 100.0%
#
#
#
#
#
# <class 'str'>

# %%
# scentence tokenizing

import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

sentences = sent_tokenize(data)

print (len(sentences))

print (sentences)
# Out:
# 27
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n2022년 01월 13일 \n\n기업분석 \n\n \n\n \n\n \n\nGS리테일 (007070) \n2022년에는 본업 회복과 시너지를 기대  \n \n\n▶Analyst 남성현 gone267@hanwha.com 3772-7651 \n\n \n\nBUY (유지) \n목표주가(유지): 60,000원 \n\n \n현재 주가(1/12) 29,600원 \n\n상승여력 ▲102.7% \n\n시가총액 30,997억원 \n\n발행주식수 104,718천주 \n\n52 주 최고가 / 최저가 39,250 / 28,250원 \n\n90 일 일평균 거래대금 66.32억원 \n\n외국인 지분율 8.1% \n\n   \n\n주주 구성  \n\nGS (외 2인) 57.9% \n\n국민연금공단 (외 1인) 8.3% \n\n자사주 (외 1 인) 2.4% \n \n \n주가수익률(%) 1개월 3개월 6개월 12개월 \n\n절대수익률 -5.7  -8.2  -18.8  -18.1  \n\n상대수익률(KOSPI) -4.5  -10.1  -10.4  -13.2  \n\n(단위: 십억 원, 원, %, 배) \n\n재무정보 2019 2020 2021E 2022E \n\n매출액 9,007  8,862  9,698  11,212  \n\n영업이익 239  253  248  355  \n\nEBITDA 898  921  968  1,161  \n\n지배주주순이익 133  168  875  362  \n\nEPS 1,729  2,187  8,771  3,454  \n\n순차입금 2,696  2,593  2,101  1,591  \n\nPER 22.7  15.7  3.5  8.6  \n\nPBR 1.4  1.2  0.8  0.7  \n\nEV/EBITDA 6.4  5.7  5.5  4.0  \n\n배당수익률 1.9  2.6  3.1  3.7  \n\nROE 6.2  7.5  27.4  8.6  \n \n \n주가 추이 \n\n \n \n\n \n\n4분기 영업실적은 부진한 흐름 이어질 전망  \n\nGS리테일 4분기 영업실적은 부진할 것으로 전망한다.', '4분기 연결기준 \n\n매출액은 2조 5,867억 원(전년동기대비 +19.7%), 영업이익 622억 원\n\n에(전년동기대비 +142.1%) 달할 것으로 추정한다.', '합병기준으로 전환\n\n해보면 매출액은 전년동기대비 +3.5%, 영업이익은 전년동기대비     \n\n-13.5%으로 분석한다.', '4분기 부진한 실적을 전망하는 근거는 1) 사회적거리두기 강화 및 추\n\n운 날씨 여파로 편의점 집객력이 하락하였고, 2) 슈퍼마켓 사업부 부진\n\n과, 3) 채널수수료 증가에 따른 홈쇼핑 비용 부담 증가가 예상되기 때\n\n문이다.', '실적 둔화에도 기대되는 이유   \n\n부진한 실적 흐름은 1분기를 기점으로 개선될 것으로 전망한다.', '그러\n\n한 이유는 1) 홈쇼핑 사업부에 대한 기저가 낮아지고, 2) 외부활동 증\n\n가에 따라 편의점 집객력 상승이 예상되며, 3) 슈퍼마켓 사업부 비수익 \n\n점포 개선 지속, 4) 홈쇼핑과의 합병 시너지가 기대되기 때문이다.', '동사는 올해 ▶ 홈쇼핑과의 시너지 본격화, ▶ 요기요와의 협업을 통한 \n\n비즈니스 모델 구축, ▶ 온·오프라인 채널 구축을 통한 차별적인 경쟁\n\n력 확보가 이루어질 것으로 전망한다.', '투자의견 BUY, 목표주가 6만원 유지  \n\n동사에 대한 투자의견 BUY와 목표주가 6만원을 유지한다.', '목표주가와 \n\n실질 주가와의 괴리율 차이가 크지만, ▶ 2022년 실적 기준 PER 수준\n\n은 8.6배에 불과하고, ▶ 연간 EBITDA 창출능력이 약 9천억원(사용권\n\n자산상각비 제외) 수준에 달하며, ▶ 주요 사업부인 편의점과 홈쇼핑 \n\n이익 창출능력이 안정적이고, ▶ 현금흐름창출능력을 기반으로 공격적\n\n인 투자가 가능한 구조라는 점에서 향후 기업가치 상승 가능성은 높은 \n\n것으로 전망한다.', '또한, 2021년 예상 DPS는 약 950원, 2022년 예상 \n\nDPS는 1,100원으로 배당매력도 높다.', '이에 투자의견 BUY와 목표주가\n\n6만원을 제시한다.', '0\n\n50\n\n100\n\n150\n\n0\n\n20,000\n\n40,000\n\n60,000\n\n21/01 21/04 21/07 21/10 22/01\n\n(pt)(원)\n\nGS리테일\n\nKOSPI지수대비\n\n\n\nGS리테일 (007070) [한화리서치] \n\n \n\n \n\n \n\n2 \n\n[표1] GS 리테일 분기 및 연간 실적 추이(연결기준)  (단위: 십억 원, %) \n\n 1Q20 2Q20 3Q20 4Q20 1Q21 2Q21 3Q21 4Q21E 2020 2021E 2022E \n\n매출액 2,141.9  2,210.7  2,348.8  2,160.9  2,100.1  2,285.6  2,725.4  2,586.7  8,862.3  9,697.8  11,212.1  \n\nYoY, % 2.8  -4.2  -1.1  -3.6  -2.0  3.4  16.0  19.7  -1.4  9.4  15.6  \n\n_편의점 1,602.8  1,762.9  1,878.6  1,727.2  1,647.9  1,816.0  1,925.2  1,778.3  6,971.5  7,167.4  7,918.1  \n\n_홈쇼핑 - - - - - - 293.1  330.0  - 623.1  1,276.1  \n\n_슈퍼마켓 345.1  314.6  389.3  284.7  298.5  297.4  326.4  278.3  1,333.7  1,200.6  1,233.9  \n\n_기타 148.7  97.2  100.3  104.8  108.5  119.5  131.2  125.1  451.0  484.3  557.5  \n\n_파르나스호텔 45.3  36.0  40.5  65.2  45.2  52.6  49.4  75.0  187.0  222.2  226.6  \n\n매출원가 1,659.5  1,763.4  1,863.1  1,745.1  1,685.4  1,835.1  2,029.8  1,849.5  7,031.0  7,399.7  8,345.9  \n\nYoY, % 0.8  -2.1  0.9  -1.4  1.6  4.1  8.9  6.0  3.5  5.2  12.8  \n\n매출총이익 482.4  447.3  485.7  415.8  414.8  450.5  695.7  737.2  1,831.3  2,298.1  2,866.2  \n\nYoY, % 10.7  -11.6  -8.1  -11.9  -14.0  0.7  43.2  77.3  4.1  25.5  24.7  \n\n매출총이익률, % 22.5  20.2  20.7  19.2  19.8  19.7  25.5  28.5  20.7  23.7  25.6  \n\n판관비 393.6  388.2  406.8  390.2  377.2  407.7  593.2  671.7  1,578.7  2,049.8  3,251.3  \n\nYoY, % -5.0  -9.5  -7.1  -7.5  -4.2  5.0  45.8  72.1  1.0  29.8  58.6  \n\n영업이익 88.8  59.2  79.0  25.7  37.5  42.8  102.5  62.2  252.6  248.4 351.0  \n\nYoY, % 314.7  -23.2  -12.8  -48.5  -57.7  -27.7  29.8  142.1  32.5  -1.6  41.3  \n\n영업이익률, % 4.1  2.7  3.4  1.2  1.8  1.9  3.8  2.4  2.8  2.6  3.1  \n \n\n주: ‘21년 3분기 GS홈쇼핑 합병 \n\n자료: GS리테일, 한화투자증권 리서치센터 \n\n \n\n \n\n  \n\n\n\nGS리테일 (007070) [한화리서치] \n\n \n\n \n\n \n\n3 \n\n [그림1] 외부활동 증가 추이 지속  ...

# %%
# word tokenizing

words = word_tokenize(data)

print(len(words))

print(words)
# Out:
# 2158
# ['2022년', '01월', '13일', '기업분석', 'GS리테일', '(', '007070', ')', '2022년에는', '본업', '회복과', '시너지를', '기대', '▶Analyst', '남성현', 'gone267', '@', 'hanwha.com', '3772-7651', 'BUY', '(', '유지', ')', '목표주가', '(', '유지', ')', ':', '60,000원', '현재', '주가', '(', '1/12', ')', '29,600원', '상승여력', '▲102.7', '%', '시가총액', '30,997억원', '발행주식수', '104,718천주', '52', '주', '최고가', '/', '최저가', '39,250', '/', '28,250원', '90', '일', '일평균', '거래대금', '66.32억원', '외국인', '지분율', '8.1', '%', '주주', '구성', 'GS', '(', '외', '2인', ')', '57.9', '%', '국민연금공단', '(', '외', '1인', ')', '8.3', '%', '자사주', '(', '외', '1', '인', ')', '2.4', '%', '주가수익률', '(', '%', ')', '1개월', '3개월', '6개월', '12개월', '절대수익률', '-5.7', '-8.2', '-18.8', '-18.1', '상대수익률', '(', 'KOSPI', ')', '-4.5', '-10.1', '-10.4', '-13.2', '(', '단위', ':', '십억', '원', ',', '원', ',', '%', ',', '배', ')', '재무정보', '2019', '2020', '2021E', '2022E', '매출액', '9,007', '8,862', '9,698', '11,212', '영업이익', '239', '253', '248', '355', 'EBITDA', '898', '921', '968', '1,161', '지배주주순이익', '133', '168', '875', '362', 'EPS', '1,729', '2,187', '8,771', '3,454', '순차입금', '2,696', '2,593', '2,101', '1,591', 'PER', '22.7', '15.7', '3.5', '8.6', 'PBR', '1.4', '1.2', '0.8', '0.7', 'EV/EBITDA', '6.4', '5.7', '5.5', '4.0', '배당수익률', '1.9', '2.6', '3.1', '3.7', 'ROE', '6.2', '7.5', '27.4', '8.6', '주가', '추이', '4분기', '영업실적은', '부진한', '흐름', '이어질', '전망', 'GS리테일', '4분기', '영업실적은', '부진할', '것으로', '전망한다', '.', '4분기', '연결기준', '매출액은', '2조', '5,867억', '원', '(', '전년동기대비', '+19.7', '%', ')', ',', '영업이익', '622억', '원', '에', '(', '전년동기대비', '+142.1', '%', ')', '달할', '것으로', '추정한다', '.', '합병기준으로', '전환', '해보면', '매출액은', '전년동기대비', '+3.5', '%', ',', '영업이익은', '전년동기대비', '-13.5', '%', '으로', '분석한다', '.', '4분기', '부진한', '실적을', '전망하는', '근거는', '1', ')', '사회적거리두기', '강화', '및', '추', '운', '날씨', '여파로', '편의점', '집객력이', '하락하였고', ',', '2', ')', '슈퍼마켓', '사업부', '부진', '과', ',', '3', ')', '채널수수료', '증가에', '따른', '홈쇼핑', '비용', '부담', '증가가', '예상되기', '때', '문이다', '.', '실적', '둔화에도', '기대되는', '이유', '부진한', '실적', '흐름은', '1분기를', '기점으로', '개선될', '것으로', '전망한다', '.', '그러', '한', '이유는', '1', ')', '홈쇼핑', '사업부에', '대한', '기저가', '낮아지고', ',', '2', ')', '외부활동', '증', '가에', '따라', '편의점', '집객력', '상승이', '예상되며', ',', '3', ')', '슈퍼마켓', '사업부', '비수익', '점포', '개선', '지속', ',', '4', ')', '홈쇼핑과의', '합병', '시너지가', '기대되기', '때문이다', '.', '동사는', '올해', '▶', '홈쇼핑과의', '시너지', '본격화', ',', '▶', '요기요와의', '협업을', '통한', '비즈니스', '모델', '구축', ',', '▶', '온·오프라인', '채널', '구축을', '통한', '차별적인', '경쟁', '력', '확보가', '이루어질', '것으로', '전망한다', '.', '투자의견', 'BUY', ',', '목표주가', '6만원', '유지', '동사에', '대한', '투자의견', 'BUY와', '목표주가', '6만원을', '유지한다', '.', '목표주가와', '실질', '주가와의', '괴리율', '차이가', '크지만', ',', '▶', '2022년', '실적', '기준', 'PER', '수준', '은', '8.6배에', '불과하고', ',', '▶', '연간', 'EBITDA', '창출능력이', '약', '9천억원', '(', '사용권', '자산상각비', '제외', ')', '수준에', '달하며', ',', '▶', '주요', '사업부인', '편의점과', '홈쇼핑', '이익', '창출능력이', '안정적이고', ',', '▶', '현금흐름창출능력을', '기반으로', '공격적', '인', '투자가', '가능한', '구조라는', '점에서', '향후', '기업가치', '상승', '가능성은', '높은', '것으로', '전망한다', '.', '또한', ',', '2021년', '예상', 'DPS는', '약', '950원', ',', '2022년', '예상', 'DPS는', '1,100원으로', '배당매력도', '높다', '.', '이에', '투자의견', 'BUY와', '목표주가', '6만원을', '제시한다', '.', '0', '50', '100', '150', '0', '20,000', '40,000', '60,000', '21/01', '21/04', '21/07', '21/10', '22/01', '(', 'pt', ')', '(', '원', ')', 'GS리테일', 'KOSPI지수대비', 'GS리테일', '(', '007070', ')', '[', '한화리서치', ']', '2', '[', '표1', ']', 'GS', '리테일', '분기', '및', '연간', '실적', '추이', '(', '연결기준', ')', '(', '단위', ':', '십억', '원', ',', '%', ')', '1Q20', '2Q20', '3Q20', '4Q20', '1Q21', '2Q21', '3Q21', '4Q21E', '2020', '2021E', '2022E', '매출액', '2,141.9', '2,210.7', '2,348.8', '2,160.9', '2,100.1', '2,285.6', '2,725.4', '2,586.7', '8,862.3', '9,697.8', '11,212.1', 'YoY', ',', '%', '2.8', '-4.2', '-1.1', '-3.6', '-2.0', '3.4', '16.0', '19.7', '-1.4', '9.4', '15.6', '_편의점', '1,602.8', '1,762.9', '1,878.6', '1,727.2', '1,647.9', '1,816.0', '1,925.2', '1,778.3', '6,971.5', '7,167.4', '7,918.1', '_홈쇼핑', '-', '-', '-', '-', '-', '-', '293.1', '330.0', '-', '623.1', '1,276.1', '_슈퍼마켓', '345.1', '314.6', '389.3', '284.7', '298.5 ...

# %%
# frequency distribution
from nltk.probability import FreqDist

# frequency 찾기
fdist = FreqDist(words)

fdist.most_common(10)
# Out:
# [(')', 82),
#  ('(', 75),
#  ('%', 42),
#  (',', 41),
#  ('.', 26),
#  ('Buy', 24),
#  ('60,000', 20),
#  ('[', 19),
#  (']', 19),
#  (':', 18)]

# %%
# plot grapy
import matplotlib.pyplot as plt

fdist.plot(10)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# remove punctutation marks
words_no_punc = []

for w in words:
    if w.isalpha():
        words_no_punc.append(w.lower())
        
print(words_no_punc)

print(len(words_no_punc))
# Out:
# ['기업분석', 'gs리테일', '본업', '회복과', '시너지를', '기대', '남성현', 'buy', '유지', '목표주가', '유지', '현재', '주가', '상승여력', '시가총액', '발행주식수', '주', '최고가', '최저가', '일', '일평균', '거래대금', '외국인', '지분율', '주주', '구성', 'gs', '외', '국민연금공단', '외', '자사주', '외', '인', '주가수익률', '절대수익률', '상대수익률', 'kospi', '단위', '십억', '원', '원', '배', '재무정보', '매출액', '영업이익', 'ebitda', '지배주주순이익', 'eps', '순차입금', 'per', 'pbr', '배당수익률', 'roe', '주가', '추이', '영업실적은', '부진한', '흐름', '이어질', '전망', 'gs리테일', '영업실적은', '부진할', '것으로', '전망한다', '연결기준', '매출액은', '원', '전년동기대비', '영업이익', '원', '에', '전년동기대비', '달할', '것으로', '추정한다', '합병기준으로', '전환', '해보면', '매출액은', '전년동기대비', '영업이익은', '전년동기대비', '으로', '분석한다', '부진한', '실적을', '전망하는', '근거는', '사회적거리두기', '강화', '및', '추', '운', '날씨', '여파로', '편의점', '집객력이', '하락하였고', '슈퍼마켓', '사업부', '부진', '과', '채널수수료', '증가에', '따른', '홈쇼핑', '비용', '부담', '증가가', '예상되기', '때', '문이다', '실적', '둔화에도', '기대되는', '이유', '부진한', '실적', '흐름은', '기점으로', '개선될', '것으로', '전망한다', '그러', '한', '이유는', '홈쇼핑', '사업부에', '대한', '기저가', '낮아지고', '외부활동', '증', '가에', '따라', '편의점', '집객력', '상승이', '예상되며', '슈퍼마켓', '사업부', '비수익', '점포', '개선', '지속', '홈쇼핑과의', '합병', '시너지가', '기대되기', '때문이다', '동사는', '올해', '홈쇼핑과의', '시너지', '본격화', '요기요와의', '협업을', '통한', '비즈니스', '모델', '구축', '채널', '구축을', '통한', '차별적인', '경쟁', '력', '확보가', '이루어질', '것으로', '전망한다', '투자의견', 'buy', '목표주가', '유지', '동사에', '대한', '투자의견', 'buy와', '목표주가', '유지한다', '목표주가와', '실질', '주가와의', '괴리율', '차이가', '크지만', '실적', '기준', 'per', '수준', '은', '불과하고', '연간', 'ebitda', '창출능력이', '약', '사용권', '자산상각비', '제외', '수준에', '달하며', '주요', '사업부인', '편의점과', '홈쇼핑', '이익', '창출능력이', '안정적이고', '현금흐름창출능력을', '기반으로', '공격적', '인', '투자가', '가능한', '구조라는', '점에서', '향후', '기업가치', '상승', '가능성은', '높은', '것으로', '전망한다', '또한', '예상', 'dps는', '약', '예상', 'dps는', '배당매력도', '높다', '이에', '투자의견', 'buy와', '목표주가', '제시한다', 'pt', '원', 'gs리테일', 'kospi지수대비', 'gs리테일', '한화리서치', 'gs', '리테일', '분기', '및', '연간', '실적', '추이', '연결기준', '단위', '십억', '원', '매출액', 'yoy', '매출원가', 'yoy', '매출총이익', 'yoy', '매출총이익률', '판관비', 'yoy', '영업이익', 'yoy', '영업이익률', '주', 'gs홈쇼핑', '합병', '자료', 'gs리테일', '한화투자증권', '리서치센터', 'gs리테일', '한화리서치', '외부활동', '증가', '추이', '지속', '주', '방문자', '중앙값', '기준', '이동평균법으로', '조정', '자료', '구글', '코로나', '지역사회', '이동성', '보고서', '한화투자증권', '리서치센터', '전년동기대비', '편의점', '기존점포', '성장률', '추이', '전년동기대비', '편의점', '품목별', '성장률', '추이', '자료', '산업통상자원부', '한화투자증권', '리서치센터', '자료', '산업통상자원부', '한화투자증권', '리서치센터', 'gs', '홈쇼핑', '모바일사업부', '취급고', '추이', '온라인시장', '규모', '동향', '자료', 'gs홈쇼핑', 'gs리테일', '한화투자증권', '리서치센터', '자료', '통계청', '한화투자증권', '리서치센터', '소매점', '및', '여가시설', '식료품점', '기존점', '담배', '등', '기타', '음료', '등', '가공', '즉석', '신선일부', '십억원', '취급고', '성장률', '우', '조원', '온라인', '시장', '성장률', '우', 'gs리테일', '한화리서치', '재무제표', '손익계산서', '단위', '십억', '원', '대차대조표', '단위', '십억', '원', '월', '결산', '월', '결산', '매출액', '유동자산', '매출총이익', '현금성자산', '영업이익', '매출채권', 'ebitda', '재고자산', '순이자손익', '비유동자산', '외화관련손익', '투자자산', '지분법손익', '유형자산', '세전계속사업손익', '무형자산', '당기순이익', '자산총계', '지배주주순이익', '유동부채', '증가율', '매입채무', '매출액', '유동성이자부채', '영업이익', '비유동부채', 'ebitda', '비유동이자부채', '순이익', '부채총계', '이익률', '자본금', '매출총이익률', '자본잉여금', '영업이익률', '이익잉여금', 'ebitda이익률', '자본조정', '세전이익률', '자기주식', '순이익률', '자본총계', '현금흐름표', '단위', '십억', '원', '주요지표', '단위', '원', '배', '월', '결산', '월', '결산', '영업현금흐름', '주당지표', '당기순이익', 'eps', '자산상각비', 'bps', '운전자본증감', 'dps', '매출채권', '감소', '증가', 'cfps', '재고자산', '감소', '증가', 'roa', '매입채무', '증가', '감소', 'roe', '투자현금흐름', 'roic', '유형자산처분', '취득', 'multiples', 'x', '무형자산', '감소', '증가', 'per', '투자자산', '감소', '증가', 'pbr', '재무현금흐름', 'psr', '차입금의', '증가', '감소', 'pcr', '자본의', '증가', '감소', '배당금의', '지급', '배당수익률', '총현금흐름', '안정성', '운전자본증가', '감소', '부채비율', '설비투자', 'net', '자산매각', 'net', 'free', 'cash', 'flow', '유동비율', '기타투자', '이자보상배율', '배', '잉여현금', '자산구조', 'noplat', '투하자본', 'dep', '운전자본투자', '자본구조', 'capex', '차입금', 'opfcf', '자기자본', '주', 'ifrs', '연결', '기준', 'gs리테일', '한화리서치', 'compliance', 'notice', '공표일', '월', '일', '이', '자료는', '조사분석', '담당자가', '객관적', '사실에', '근거해', '작성하였으며', '타인의', '부당한', '압력이나', '간섭없이', '본인의', '의견을', '정확하게', '반영했습니다', '본인은', '이', '자료에서', '다룬', '종목과', '관련해', '공표일', '현재', '관련', '법규상', '알려야', '할', '재산적', '이해관계가', '없습니다', '본인은', '이', '자료를', '기관투자자', '또는', '자에게', '사전에', '제공한', '사실이', '없습니다' ...
# 821

# %%
fdist = FreqDist(words_no_punc)
fdist.most_common(10)
# Out:
# [('buy', 26),
#  ('원', 12),
#  ('gs리테일', 11),
#  ('투자의견', 11),
#  ('목표주가', 9),
#  ('것으로', 8),
#  ('증가', 8),
#  ('감소', 8),
#  ('일', 7),
#  ('추이', 7)]

# %%
fdist.plot(10)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
from nltk.corpus import stopwords

# List of stopwords
stopwords = stopwords.words("english")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from konlpy.tag import Okt

okt = Okt()
stop_words = set(stopwords.words('english')) 
word_tokens = okt.morphs(data)

result = [word for word in word_tokens if not word in stop_words]
print(result)
# Out:
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n', '2022년', '01월', '13일', '기업', '분석', 'GS', '리테일', '(', '007070', ')', '2022년', '에는', '본업', '회복', '과', '시너지', '를', '기대', '▶', 'Analyst', '남성현', 'gone267@hanwha.com', '3772-7651', 'BUY', '(', '유지', ')', '목표', '주가', '(', '유지', '):', '60,000원', '현재', '주가', '(', '1/12', ')', '29,600원', '상승', '여력', '▲', '102.7%', '시가총액', '30,997억원', '발행', '주', '식수', '104,718천', '주', '52', '주', '최고', '가', '/', '최저', '가', '39,250', '/', '28,250원', '90', '일', '일', '평균', '거래', '대금', '66.32억원', '외국인', '지', '분율', '8.1%', '주주', '구성', 'GS', '(', '외', '2', '인', ')', '57.9%', '국민연금', '공단', '(', '외', '1', '인', ')', '8.3%', '자', '사주', '(', '외', '1', '인', ')', '2.4%', '주가수익률', '(%)', '1', '개월', '3', '개월', '6', '개월', '12', '개월', '절대', '수익률', '-', '5.7', '-', '8.2', '-', '18.8', '-', '18.1', '상대', '수익률', '(', 'KOSPI', ')', '-', '4.5', '-', '10.1', '-', '10.4', '-', '13.2', '(', '단위', ':', '십억', '원', ',', '원', ',', '%,', '배', ')', '재무', '정보', '2019', '2020', '2021', 'E', '2022', 'E', '매출', '액', '9,007', '8,862', '9,698', '11,212', '영업', '이익', '239', '253', '248', '355', 'EBITDA', '898', '921', '968', '1,161', '지배', '주', '주', '순이익', '133', '168', '875', '362', 'EPS', '1,729', '2,187', '8,771', '3,454', '순차', '입금', '2,696', '2,593', '2,101', '1,591', 'PER', '22.7', '15.7', '3.5', '8.6', 'PBR', '1.4', '1.2', '0.8', '0.7', 'EV', '/', 'EBITDA', '6.4', '5.7', '5.5', '4.0', '배당', '수익률', '1.9', '2.6', '3.1', '3.7', 'ROE', '6.2', '7.5', '27.4', '8.6', '주가', '추이', '4분', '기', '영업', '실적', '은', '부진한', '흐름', '이어질', '전망', 'GS', '리테일', '4분', '기', '영업', '실적', '은', '부진할', '것', '으로', '전망', '한다', '.', '4분', '기', '연결', '기준', '매출', '액', '은', '2조', '5,867억', '원', '(', '전', '년', '동', '기', '대비', '+', '19.7%', '),', '영업', '이익', '622억', '원', '\n\n', '에', '(', '전', '년', '동', '기', '대비', '+', '142.1%', ')', '달', '할', '것', '으로', '추정', '한다', '.', '합병', '기준', '으로', '전환', '\n\n', '해보면', '매출', '액', '은', '전', '년', '동', '기', '대비', '+', '3.5%', ',', '영업', '이익', '은', '전', '년', '동', '기', '대비', '-', '13.5%', '으로', '분석', '한다', '.', '4분', '기', '부진한', '실적', '을', '전망', '하는', '근거', '는', '1', ')', '사회', '적', '거리', '두기', '강화', '및', '추', '\n\n', '운', '날씨', '여파', '로', '편의점', '집객', '력', '이', '하락', '하였고', ',', '2', ')', '슈퍼마켓', '사업', '부', '부진', '\n\n', '과', ',', '3', ')', '채널', '수수료', '증가', '에', '따른', '홈쇼핑', '비용', '부담', '증가', '가', '예상', '되기', '때', '\n\n', '문', '이다', '.', '실적', '둔화', '에도', '기대', '되는', '이유', '부진한', '실적', '흐름', '은', '1분', '기를', '기점', '으로', '개선', '될', '것', '으로', '전망', '한다', '.', '그러', '\n\n', '한', '이유', '는', '1', ')', '홈쇼핑', '사업', '부', '에', '대한', '기저', '가', '낮아지고', ',', '2', ')', '외부', '활동', '증', '\n\n', '가에', '따라', '편의점', '집객', '력', '상승', '이', '예상', '되며', ',', '3', ')', '슈퍼마켓', '사업', '부', '비', '수익', '점포', '개선', '지속', ',', '4', ')', '홈쇼핑', '과의', '합병', '시너지', '가', '기대되', '기', '때문', '이다', '.', '동사', '는', '올해', '▶', '홈쇼핑', '과의', '시너지', '본격', '화', ',', '▶', '요', '기요', '와의', '협업', '을', '통한', '비즈니스', '모델', '구축', ',', '▶', '온', '·', '오프라인', '채널', '구축', '을', '통한', '차별', '적', '인', '경쟁', '\n\n', '력', '확보', '가', '이루어질', '것', '으로', '전망', '한다', '.', '투자', '의견', 'BUY', ',', '목표', '주가', '6만원', '유지', '동사', '에', '대한', '투자', '의견', 'BUY', '와', '목표', '주가', '6만원', '을', '유지', '한다', '.', '목표', '주가', '와', '실질', '주가', '와의', '괴리율', '차이', '가', '크지만', ',', '▶', '2022년', '실적', '기준', 'PER', '수준', '\n\n', '은', '8.6', '배', '에', '불과하고', ',', '▶', '연간', 'EBITDA', '창', '출', '능력', '이', '약', '9천억원', '(', '사용권', '\n\n', '자산', '상', '각', '비', '제외', ')', '수준', '에', '달', '하며', ',', '▶', '주요', '사업', '부인', '편의점', '과', '홈쇼핑', '이익', '창', '출', '능력', '이', '안정', '적', '이고', ',', '▶', '현금', '흐름', '창', '출', '능력', '을', '기반', '으로', '공격', '적', '\n\n', '인', '투자가', '가능한', '구조', '라는', '점', '에서', '향후', '기업', '가치', '상승', '가능성', '은', '높은', '것', '으로', '전망', '한다', '.', '또한', ',', '2021년', '예상', 'DPS', '는', '약', '950원', ',', '2022년', '예상', 'DPS', '는', '1,100원', '으로', '배당', '매력', '도', '높다', '.', '이', '에', '투자', '의견', 'BUY', '와', '목표', '주가', '\n\n', '6만원', '을', '제', '시한',  ...
